# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

url = 'https://raw.githubusercontent.com/Haeeshart/Python-for-Biologists/refs/heads/main/Global%20difference%20(1).csv'
df = pd.read_csv(url)
df.head()
# Out:
#         Gene       WT_1       WT_2       WT_3     hnox_1     hnox_2     hnox_3
# 0  Pden_0001  15.257661  15.466992  15.106084  15.163709  15.350200  15.330972
# 1        rho  19.323959  19.185708  19.439069  18.638041  18.898438  18.546545
# 2       mnmE  17.310870  17.453550  17.548070  17.745923  17.844168  17.708122
# 3       mnmG  20.292848  20.373691  20.448830  20.301087  20.528667  20.162374
# 4       rsmG  19.390807  19.493019  19.472492  19.444374  19.413354  19.539371

# %%
df.dropna(inplace = True)
print(df.shape)
# Out:
# (2678, 7)

# %%
df = df.set_index('Gene')

# %%
sns.clustermap(df, metric="euclidean", z_score=0, method="average",cmap="vanimo")
png_path = 'HeatMAp.png'
pdf_path = 'HeatMAp.pdf'
plt.savefig(png_path, dpi=600)
plt.savefig(pdf_path)
plt.show()

# heatmap shows replicates are nicely clustered amongst each strain. Replicates are similar for both WT and deleted hnox but the strains themselves
# are different from each other
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
sns.clustermap(df, metric="Correlation", z_score=0, method="average", cmap="vanimo")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# Use seaborn style
sns.set()

url = 'https://raw.githubusercontent.com/Haeeshart/Python-for-Biologists/refs/heads/main/Global%20difference%20(1).csv'
df = pd.read_csv(url)
df.head()

print(df.keys())
print(df.shape)
df


df.dropna(inplace = True)
print(df.shape)
df = df.set_index('Gene')

sns.clustermap(df, metric="euclidean", z_score=0, method="average", cmap="vanimo")
plt.savefig("Heat_Pden1.pdf")
plt.show()
# Out:
# Index(['Gene', 'WT_1', 'WT_2', 'WT_3', 'hnox_1', 'hnox_2', 'hnox_3'], dtype='object')
# (2694, 7)
# (2678, 7)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
